# %% [markdown]
# # Python Questions

# %%
# Print 'enna thudangiyalo?'
print('enna thudangiyalo?')
# Out:
# enna thudangiyalo?

# %%
# take user name as input and store it in a variable called 'name'
name = input('What is your name?')
name
# Out:
# What is your name?Akshay
# 'Akshay'

# %%
# Take user input for age and check its data type
age = input('How old are you? ')
type(age)
# Out:
# How old are you? 25
# str

# %%
# typecast the data type of  age to 'int'
age = int(age)

# %%
type(age)
# Out:
# int

# %%
# or
age = int(input('How old are you? '))
type(age)
# Out:
# How old are you? 25
# int

# %%
# print '*****'
print('*****')
print('*'*5)
print('#'*5)
# Out:
# *****
# *****
# #####

# %%
# type cast the following integer to string
value = 45 
value2 = str(value)
type(value2)
# Out:
# str

# %%
# Write a program that takes 'year of birth' of users as input and prints the age of user
yb = int(input('which year were you born? '))
age = 2023 - yb
print('You are {} years old'.format(age))
# Out:
# which year were you born? 1998
# You are 25 years old

# %%
# print the remainder of the number 100 when divided by 19 
print(100%19)
# Out:
# 5

# %%
# Add your first name, last name and age using multi line comments
'''
Akshay
Pattayil
25


'''
print('sdfsdgs')
# Out:
# sdfsdgs

# %%
# identify the error and fix it
print('It\'s just a beginning')
# Out:
# It's just a beginning

# %%
# print the number of characters in the string 'Akshay Pattayil'
string =  'Akshay Pattayil'
len(string)
# Out:
# 15

# %%
# Extract 'sh' from string (slicing) and store it in s1
s1 = string[2:4]
s1
# Out:
# 'sh'

# %%
# obtain 6th character from string and store it in s2
s2 = string[5]
s2
# Out:
# 'y'

# %%
# concatenate s1 and s2
s1 + s2
# Out:
# 'shy'

# %%
# remove the extra spaces from both sides of the below string
st = '          you guys are awesome        '
st.strip()
# Out:
# 'you guys are awesome'
