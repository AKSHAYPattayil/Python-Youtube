# %% [markdown]
# ## Tuples

# %% [markdown]
# In Python, a tuple is an ordered collection of elements, enclosed in parentheses (). Tuples are similar to lists, but with one key difference: tuples are immutable, meaning their elements cannot be modified once created.

# %%
['Sadie sink',21, 'Hello']
# Out:
# ['Sadie sink', 21, 'Hello']

# %%
t = ('Sadie sink',21, 'Hello')
print(t)
type(t)
# Out:
# ('Sadie sink', 21, 'Hello')
# tuple

# %% [markdown]
# #### Different ways of declaring a tuple

# %% [markdown]
#     1. Using Parentheses

# %%
t = ('Sadie sink',21, 'Hello')
print(t)
type(t)
# Out:
# ('Sadie sink', 21, 'Hello')
# tuple

# %%
# single value tuple
t = (2,)
type(t)
# Out:
# tuple

# %% [markdown]
#     2. using comma separated elements (Without parentheses)

# %%
t = 'Sadie sink',21, 'Hello'
print(t)
type(t)
# Out:
# ('Sadie sink', 21, 'Hello')
# tuple

# %%
# single value tuple
t = 2,
type(t)
# Out:
# tuple

# %% [markdown]
#     3. Using tuple() constructor c
# tuple() constructor to creates a tuple from an iterable, such as a list or a string.

# %%
l = ['Sadie sink',21, 'Hello']
tuple(l)
# Out:
# ('Sadie sink', 21, 'Hello')

# %%
s = 'Akshay Pattayil'
tuple(s)
# Out:
# ('A', 'k', 's', 'h', 'a', 'y', ' ', 'P', 'a', 't', 't', 'a', 'y', 'i', 'l')

# %% [markdown]
#     4. Using tuple packing
#
# Tuple packing allows you to create a tuple by assigning multiple values to a single tuple variable

# %%
v1 = 'meesakkaran'
v2 = 'Madhavan'
v3 = 453

# %%
t = v1,v2,v3
print(t)
type(t)
# Out:
# ('meesakkaran', 'Madhavan', '453')
# tuple

# %% [markdown]
# #### Nested tuple

# %% [markdown]
# Tuples can contain other tuples, allowing you to create nested structures

# %%
t = (45,'f',(3,4),34)
type(t)
# Out:
# tuple

# %%
t = (45,'f',[3,4],34)
type(t)
# Out:
# tuple

# %%
# number of elements
len(t)
# Out:
# 4

# %% [markdown]
# #### Indexing and slicing

# %% [markdown]
#     ##### DON'T TYPE
# **Tuples are ordered sequences, which means the order in which the elements are inserted remains the same. This makes them flexible for indexing and slicing just like lists. Using slicing,**

# %%
t = (45,'fame',[3,4],34)

# %%
t[0]
# Out:
# 45

# %%
t[1]
# Out:
# 'f'

# %%
t[-1]
# Out:
# 34

# %%
t[2][0]
# Out:
# 3

# %%
t[1][2]
# Out:
# 'm'

# %%
# slicing
t[0:3]
# Out:
# (45, 'f', [3, 4])

# %%
t[1:3]
# Out:
# ('f', [3, 4])

# %%
# last two elements
t[-2:]
# Out:
# ([3, 4], 34)

# %% [markdown]
# #### tuple concatenation

# %%
t1 = 
t2 = 

t3 = t1+t2

# %% [markdown]
# #### sum() - min() - max()

# %%
t=(45,1,2,6,8,78,2,6,-4)
print(max(t),'\n',min(t),'\n',sum(t))
# Out:
# 78
#  -4
#  144

# %% [markdown]
# #### Immutability

# %% [markdown]
# #Tuples are similar to lists, but with one key difference: tuples are immutable, meaning their elements cannot be modified once created.

# %%
    my_tuple = ('apple', 'banana', 'cherry', 'date')
my_tuple[1] = 'grape'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14660/418565162.py in <module>
#       1 my_tuple = ('apple', 'banana', 'cherry', 'date')
# ----> 2 my_tuple[1] = 'grape'
#
# TypeError: 'tuple' object does not support item assignment

# %%
new_t = my_tuple[0]+('grape',)+ my_tuple[2:]
new_t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14660/163748201.py in <module>
# ----> 1 new_t = my_tuple[0]+('grape',)+ my_tuple[2:]
#       2 new_t
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
type(my_tuple[0])
# Out:
# str

# %%
new_t = my_tuple[:1]+('grape',)+ my_tuple[2:]
new_t
# Out:
# ('apple', 'grape', 'cherry', 'date')

# %%
## Can you add an element to a tuple?

# %%
t = ('Akshay','Pattayil','Jupyter')

# %%
t+('python',)
# Out:
# (1, 2, 45, 6, 'sf', 'python')

# %%
# adding element to a speified index

# %%
l = list(t)
l.insert(1,'Python')

# %%
tuple(l)
# Out:
# ('Akshay', 'Python', 'Pattayil', 'Jupyter')

# %% [markdown]
# #### sorting a tuple

# %%
l = [2,33,4,2,1,65]

# %%
sorted(l)
# Out:
# [1, 2, 2, 4, 33, 65]

# %%
l
# Out:
# [2, 33, 4, 2, 1, 65]

# %%
l.sort()
l
# Out:
# [1, 2, 2, 4, 33, 65]

# %%
t = (23,1,3,4,232,8)

# %%
tuple(sorted(t))
# Out:
# (1, 3, 4, 8, 23, 232)

# %% [markdown]
# #### Packing and unpacking

# %% [markdown]
# **Packing**
#     - to create a tuple by assigning multiple values to a single tuple variable
#
# **unpacking**
#     - extracting values from a tuple and assigning them to separate variables.
#
# **Extended unpacking**
#     -  to assign multiple values from a tuple to a single variable or capture a subset of values.

# %%
# packing
t = v1,v2,v3
print(t)
# Out:
# ('meesakkaran', 'Madhavan', '453')

# %%
# unpacking
a,b,c = t

# %%
c
# Out:
# '453'

# %%
# extended unpacking
t = (1,2,45,6,'sf')

# %%
a,*b,c = t

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
c
# Out:
# [45, 6, 'sf']

# %% [markdown]
# - Packing allows you to group values into a tuple, while unpacking enables you to extract values from a tuple and assign them to individual variables,

# %% [markdown]
# #### Help

# %%
# brief description of each of the methods available with tuples:
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...
