# %% [markdown]
# - During edit mode cells appear in green

# %% [markdown]
# - Coding cell and Markdown cell

# %%
#this is a coding cell
print("Akshay Pattayil")
# Out:
# Akshay Pattayil

# %% [markdown]
# This is a markdown cell
#
# Akshay Pattayil
# markdown cell- used for explanatory texts

# %% [markdown]
# #### Use # for adding comments in a coding cell

# %%
# This is a comment written inside a coding cell
print('Akshay Pattayil')
# Out:
# Akshay Pattayil

# %% [markdown]
# #### Converting cells

# %%
#### I am a coding cell, but I want to be Markdown cell

# press 'M' to convert a coding cell to markdown

# %% [markdown]
# ##### press 'Y' to convert a markdown cell to coding cell
#
# A="Enne Coding cell aakkan pattuo,Sakkeer bhaik"
# print(A)

# %% [markdown]
# ### shortcuts

# %%
# Delete the cell below by pressinf 'D' two times
# Press 'Enter' to edit the cell and  press 'Esc' for going back to command mode
# press Shift + Enter to execute the code and go to the next cell
# M: To convert a cell to a markdown cell
# C : copy , X : cut V:Paste
# Ctrl + Shift + -: To split the cell at cursor
# Shift + M: To merge selected cells

# %%
# Press h for more shortcuts

# %% [markdown]
# <h1 style="color:Brown"> Markdown cell

# %% [markdown]
# #### Headings

# %% [markdown]
# -  Use # for creating headings in a Markdown cell

# %% [markdown]
# # Heading

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# #### Formatting

# %% [markdown]
# - Format the following sentence

# %% [markdown]
#    "Ration kada innu avadhi aanu"

# %% [markdown]
# 1. Italic

# %%
#Use one dash
#use one star

# %% [markdown]
# *Ration kada innu thurannittilla*

# %% [markdown]
# 2. Bold

# %%
#Use two dashes
#Use two stars

# %% [markdown]
# **Ration kada innu thurannittilla**

# %% [markdown]
# 3. Both bold and italic

# %%
#Use three dashes
#use three stars

# %% [markdown]
# ***Ration kada innu thurannittilla***

# %% [markdown]
# 4. Line break

# %% [markdown]
# Abhijith F
# arts

# %% [markdown]
# Abhijith F <br>
# arts

# %% [markdown]
# 5. coloring

# %%
#coloring a sentence in markdown

# %% [markdown]
# <font color = 'red'> this is colored sentence

# %%
# coloring a word in a sentence

# %% [markdown]
# coloring a <font color='red'>word</font> in a sentence

# %% [markdown]
# 6. Bullets  Numbering

# %%
# Create a bullet by pressing a dash followed by space
# Create a sub bullet by pressing tab,dash and space
# create a numbered list by pressing number followed by a dot and space
# create sub bullets for a numbered list

# %% [markdown]
# -  Create a bullet by pressing a dash followed by space
#     - Create a sub bullet by pressing tab,dash and space

# %% [markdown]
# 1. create a numbered list by pressing number followed by a dot and space
# 2. asksbldasb
#     1. bhvsa

# %% [markdown]
# 7. Indenting

# %%
# Write your sentence
#Use > to indent your next line

# %% [markdown]
# This is the first line
# >this is the second line
# >>this is the third line

# %% [markdown]
# <h1 style="color:brown"> Yeei!!!!
#     Great Job guys.<br>
#     Now you can get started with Python in Jupyter Notebook...
