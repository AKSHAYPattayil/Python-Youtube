# %%
# Install jupyter-theme package
# !pip install jupyterthemes
# Out:
# Requirement already satisfied: jupyterthemes in c:\users\aksha\anaconda3\lib\site-packages (0.20.0)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
#List the available themes in the package
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# change the theme
# !jt -t chesterish

# %%
# !jt -t grade3

# %%
# reverse your changes
